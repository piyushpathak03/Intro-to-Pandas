# %%
import pandas as pd
reviews = pd.read_csv("ign.csv",encoding='GBK')

# %%
reviews.head() 
# for printing first N number of  starting rows , bt default it prints first 5 rows
# Out:
#    Unnamed: 0  X score_phrase  \
# 0           1  0      Amazing
# 1           2  1      Amazing
# 2           3  2        Great
# 3           4  3        Great
# 4           5  4        Great
#
#                                                title  \
# 0                            LittleBigPlanet PS Vita
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                               Splice: Tree of Life
# 3                                             NHL 13
# 4                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# ...

# %%
reviews.tail() 
# for printing last N rows of the dataset,by default it prints last 5 rows
# Out:
#        Unnamed: 0      X score_phrase  \
# 18584       18621  18620         Good
# 18585       18622  18621      Amazing
# 18586       18623  18622     Mediocre
# 18587       18624  18623  Masterpiece
# 18588       18625  18624  Masterpiece
#
#                                          title  \
# 18584                Tokyo Mirage Sessions #FE
# 18585        LEGO Star Wars: The Force Awakens
# 18586  Star Ocean: Integrity and Faithlessness
# 18587                                   Inside
# 18588                                   Inside
#
#                                                      url       platform  \
# 18584  /games/fire-emblem-x-shin-megami-tensei/wii-u-...          Wii U
# 18585  /games/lego-star-wars-the-force-awakens/ps4-20...  PlayStation 4
# 18586                   /games/star-ocean-5/ps4-20035681  PlayStation 4
# 18587             /games/inside-playdead/xbox-one-121435       Xbox One
# 18588                 /games/inside-playdead/pc-20055740             PC
#
# ...

# %%
reviews.shape
# Return a tuple representing the dimensionality of the DataFrame.
# Out:
# (18589, 13)

# %%
reviews.iloc[0:10,3:12]
# used for working with specific rows in hue datasets
# Out:
#                                                title  \
# 0                            LittleBigPlanet PS Vita
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                               Splice: Tree of Life
# 3                                             NHL 13
# 4                                             NHL 13
# 5                          Total War Battles: Shogun
# 6                                Double Dragon: Neon
# 7                                       Guild Wars 2
# 8                                Double Dragon: Neon
# 9                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# ...

# %%
reviews = reviews.iloc[:,2:]

# %%
reviews.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre genre2 editors_choice  release_year  release_month  release_day
# ...

# %%
reviews.loc[0:5,"title":]
# Access a group of rows and columns by label(s) or a boolean array.
# Out:
#                                                title  \
# 0                            LittleBigPlanet PS Vita
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                               Splice: Tree of Life
# 3                                             NHL 13
# 4                                             NHL 13
# 5                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
# 5         /games/total-war-battles-shogun/mac-142565         Macintosh    7.0
#
# ...

# %%
some_reviews = reviews.iloc[10:20,:]
some_reviews.head()
# creating a subset using iloc[]
# Out:
#    score_phrase                            title  \
# 10         Good          Tekken Tag Tournament 2
# 11         Good          Tekken Tag Tournament 2
# 12      Amazing                Mark of the Ninja
# 13      Amazing                Mark of the Ninja
# 14         Okay  Home: A Unique Horror Adventure
#
#                                                   url       platform  score  \
# 10          /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11     /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12    /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# 13          /games/mark-of-the-ninja-135615/pc-143761             PC    9.0
# 14  /games/home-a-unique-horror-adventure/mac-2001...      Macintosh    6.5
#
#         genre     genre2 editors_choice  release_year  release_month  \
# 10   Fighting        NaN              N          2012              9
# 11   Fighting        NaN              N          2012              9
# ...

# %%
reviews.loc[:5,["score","title"]]
# giving more than one column label
# Out:
#    score                                              title
# 0    9.0                            LittleBigPlanet PS Vita
# 1    9.0  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2    8.5                               Splice: Tree of Life
# 3    8.5                                             NHL 13
# 4    8.5                                             NHL 13
# 5    7.0                          Total War Battles: Shogun

# %%
type(reviews["score"])
# to check if it is series or not
# Out:
# pandas.core.series.Series

# %%
reviews["title"].head()
# Out:
# 0                              LittleBigPlanet PS Vita
# 1    LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                 Splice: Tree of Life
# 3                                               NHL 13
# 4                                               NHL 13
# Name: title, dtype: object

# %%
reviews.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre genre2 editors_choice  release_year  release_month  release_day
# ...

# %%
reviews["score"].mean()
# for calling the mean of a single column
# Out:
# 6.950852654795847

# %%
reviews.mean()
# getting the mean for all the columns axis =0
# Out:
# score               6.950853
# release_year     2006.508634
# release_month       7.139868
# release_day        15.601431
# dtype: float64

# %%
reviews.mean(axis=1)
#  getting the mean for all the rows axis =1
# Out:
# 0        510.500
# 1        510.500
# 2        510.375
# 3        510.125
# 4        510.125
# 5        509.750
# 6        508.750
# 7        510.250
# 8        508.750
# 9        509.750
# 10       509.875
# 11       509.875
# 12       509.250
# 13       509.250
# 14       508.375
# 15       508.375
# 16       508.500
# 17       507.375
# 18       507.750
# 19       507.750
# 20       514.625
# 21       514.625
# 22       514.625
# 23       515.000
# 24       514.250
# 25       514.750
# 26       514.125
# 27       514.250
# 28       513.625
# 29       514.250
#           ...
# 18559    510.850
# 18560    510.875
# 18561    510.225
# 18562    510.700
# 18563    510.750
# 18564    512.600
# 18565    512.600
# 18566    512.600
# 18567    512.450
# 18568    512.400
# 18569    511.500
# 18570    508.600
# 18571    510.750
# 18572    510.350
# 18573    510.750
# 18574    510.250
# 18575    508.700
# 18576    509.200
# 18577    508.000
# 18578    515.050
# 18579    515.050
# ...

# %%
reviews.corr(method='pearson',min_periods=2)
# Compute pairwise correlation of columns, excluding NA/null values
# Out:
#                   score  release_year  release_month  release_day
# score          1.000000      0.062952       0.007765     0.020410
# release_year   0.062952      1.000000      -0.115194     0.016472
# release_month  0.007765     -0.115194       1.000000    -0.067407
# release_day    0.020410      0.016472      -0.067407     1.000000

# %%
reviews.count()
# returns the count of each column
# Out:
# score_phrase      18589
# title             18589
# url               18589
# platform          18589
# score             18589
# genre             18589
# genre2             2617
# editors_choice    18589
# release_year      18589
# release_month     18589
# release_day       18589
# dtype: int64

# %%
reviews.max()
#  for getting the max values
# Out:
# score_phrase                       Unbearable
# title                 xXx: State of the Union
# url               /games/zusar-vasar/dc-13794
# platform                                 iPod
# score                                      10
# genre                               Wrestling
# editors_choice                              Y
# release_year                             2016
# release_month                              12
# release_day                                31
# dtype: object

# %%
reviews.min()
#  for finding the min value of the columns
# Out:
# score_phrase                                     Amazing
# title                                             #IDARB
# url               /games/0-d-beat-drop/xbox-360-14342395
# platform                                         Android
# score                                                0.5
# genre                                             Action
# editors_choice                                         N
# release_year                                        1970
# release_month                                          1
# release_day                                            1
# dtype: object

# %%
reviews.median()
# for finding the median of the columns
# Out:
# score               7.3
# release_year     2007.0
# release_month       8.0
# release_day        16.0
# dtype: float64

# %%
reviews.std()
# for finding standard deviation of the columns
# Out:
# score            1.712078
# release_year     4.588687
# release_month    3.477048
# release_day      8.692460
# dtype: float64

# %%
reviews["score"]/2
# for getting a scale of 1-10 to 1-5
# Out:
# 0        4.50
# 1        4.50
# 2        4.25
# 3        4.25
# 4        4.25
# 5        3.50
# 6        1.50
# 7        4.50
# 8        1.50
# 9        3.50
# 10       3.75
# 11       3.75
# 12       4.50
# 13       4.50
# 14       3.25
# 15       3.25
# 16       4.00
# 17       2.75
# 18       3.50
# 19       3.50
# 20       3.75
# 21       3.75
# 22       3.75
# 23       4.50
# 24       3.50
# 25       4.50
# 26       3.75
# 27       4.00
# 28       3.25
# 29       4.50
#          ...
# 18559    2.20
# 18560    3.25
# 18561    2.45
# 18562    3.40
# 18563    3.50
# 18564    3.70
# 18565    3.70
# 18566    3.70
# 18567    3.90
# 18568    4.30
# 18569    3.00
# 18570    3.20
# 18571    3.50
# 18572    2.70
# 18573    4.00
# 18574    3.00
# 18575    2.90
# 18576    3.90
# 18577    4.00
# 18578    4.60
# 18579    4.60
# 18580    3.75
# 18581    4.20
# 18582    4.55
# 18583    3.95
# 18584    3.80
# 18585    4.50
# 18586    2.90
# 18587    5.00
# 18588    5.00
# ...

# %%
score_filter = reviews["score"]>7
score_filter
# for Boolean indexing
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5        False
# 6        False
# 7         True
# 8        False
# 9        False
# 10        True
# 11        True
# 12        True
# 13        True
# 14       False
# 15       False
# 16        True
# 17       False
# 18       False
# 19       False
# 20        True
# 21        True
# 22        True
# 23        True
# 24       False
# 25        True
# 26        True
# 27        True
# 28       False
# 29        True
#          ...
# 18559    False
# 18560    False
# 18561    False
# 18562    False
# 18563    False
# 18564     True
# 18565     True
# 18566     True
# 18567     True
# 18568     True
# 18569    False
# 18570    False
# 18571    False
# 18572    False
# 18573     True
# 18574    False
# 18575    False
# 18576     True
# 18577     True
# 18578     True
# 18579     True
# 18580     True
# 18581     True
# 18582     True
# 18583     True
# 18584     True
# 18585     True
# ...

# %%
filter_reviews = reviews[score_filter]
filter_reviews.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre genre2 editors_choice  release_year  release_month  release_day
# ...

# %%
new_filter = (reviews["score"]>7) & (reviews["platform"]=="Xbox 360")
filter_reviews = reviews[new_filter]
filter_reviews.head()
# way to apply multiple filters
# Out:
#    score_phrase                                              title  \
# 3         Great                                             NHL 13
# 11         Good                            Tekken Tag Tournament 2
# 12      Amazing                                  Mark of the Ninja
# 20         Good                           Mass Effect 3: Leviathan
# 36      Amazing  The Walking Dead: The Game -- Episode 3: Long ...
#
#                                                   url  platform  score  \
# 3                       /games/nhl-13/xbox-360-128182  Xbox 360    8.5
# 11     /games/tekken-tag-tournament-2/xbox-360-124581  Xbox 360    7.5
# 12    /games/mark-of-the-ninja-135615/xbox-360-129276  Xbox 360    9.0
# 20     /games/mass-effect-3-leviathan/xbox-360-138918  Xbox 360    7.5
# 36  /games/the-walking-dead-season-1-episode-3/xbo...  Xbox 360    9.0
#
#         genre     genre2 editors_choice  release_year  release_month  \
# ...

# %%
# %matplotlib inline
reviews[reviews["platform"]=="Xbox 360"]["score"].plot(kind="hist")
# for plotting

# %%
# %matplotlib inline
reviews[reviews["platform"]=="PlayStation 4"]["score"].plot(kind="hist")

# %%
filter_reviews["score"].hist()
